# %% [markdown]
# # Statistical Analysis - Python
#
# ## Overview
# This notebook performs descriptive, inferential, and exploratory statistical analysis.
#
# This notebook performs the analysis. You can also run the corresponding script:
# `scripts/python/statistical_analysis.py`

# %% [markdown]
# ## Run Analysis Script
#
# The following cell runs the complete analysis script.

# %%
# Change to scripts directory
import os
import sys
os.chdir('../../scripts/python')

# Run the script
exec(open('statistical_analysis.py').read())

# Change back
os.chdir('../../notebooks/python')

# %% [markdown]
# ## Interactive Analysis
#
# You can also perform interactive analysis in the cells below.
