# %% [markdown]
# # Univariate, Bivariate, and Multivariate Analysis - R
#
# ## Overview
# This notebook performs univariate, bivariate, and multivariate analysis using R.
#
# This notebook performs the analysis using R. You can also run the corresponding R script:
# `scripts/R/univariate_bivariate_multivariate.R`

# %% [markdown]
# ## Run Analysis Script
#
# The following cell runs the complete analysis script.

# %%
# Change to scripts directory
setwd('../../scripts/R')

# Run the script
source('univariate_bivariate_multivariate.R')

# Change back
setwd('../../notebooks/R')
