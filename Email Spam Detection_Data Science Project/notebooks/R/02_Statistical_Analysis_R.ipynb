# %% [markdown]
# # Statistical Analysis - R
#
# ## Overview
# This notebook performs descriptive, inferential, and exploratory statistical analysis using R.
#
# This notebook performs the analysis using R. You can also run the corresponding R script:
# `scripts/R/statistical_analysis.R`

# %% [markdown]
# ## Run Analysis Script
#
# The following cell runs the complete analysis script.

# %%
# Change to scripts directory
setwd('../../scripts/R')

# Run the script
source('statistical_analysis.R')

# Change back
setwd('../../notebooks/R')
