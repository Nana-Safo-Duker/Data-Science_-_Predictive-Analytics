# %% [markdown]
# # Exploratory Data Analysis (EDA) - R
#
# ## Overview
# This notebook provides comprehensive Exploratory Data Analysis using R.
#
# This notebook performs the analysis using R. You can also run the corresponding R script:
# `scripts/R/eda.R`

# %% [markdown]
# ## Run Analysis Script
#
# The following cell runs the complete analysis script.

# %%
# Change to scripts directory
setwd('../../scripts/R')

# Run the script
source('eda.R')

# Change back
setwd('../../notebooks/R')
