# %% [markdown]
# # Machine Learning Analysis
#
# Machine learning analysis using R with various algorithms.
#
# This notebook runs the R script: `scripts/r/ml_analysis.R`

# %%
# Set working directory
setwd('../../')

# Source the R script
source('scripts/r/ml_analysis.R')
