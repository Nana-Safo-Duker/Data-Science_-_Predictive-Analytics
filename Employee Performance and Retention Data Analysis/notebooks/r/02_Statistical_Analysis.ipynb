# %% [markdown]
# # Statistical Analysis
#
# Descriptive, inferential, and exploratory statistical analysis using R.
#
# This notebook runs the R script: `scripts/r/statistical_analysis.R`

# %%
# Set working directory
setwd('../../')

# Source the R script
source('scripts/r/statistical_analysis.R')
