# %% [markdown]
# # Univariate, Bivariate, and Multivariate Analysis
#
# Univariate, bivariate, and multivariate analysis using R.
#
# This notebook runs the R script: `scripts/r/univariate_bivariate_multivariate.R`

# %%
# Set working directory
setwd('../../')

# Source the R script
source('scripts/r/univariate_bivariate_multivariate.R')
